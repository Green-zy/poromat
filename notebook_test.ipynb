# %%
import sys
sys.path.append("src")

# %%
import poromat
# Out:
# /Users/robbie/miniforge3/envs/poromat/lib/python3.10/site-packages/torchvision/io/image.py:14: UserWarning: Failed to load image Python extension: 'dlopen(/Users/robbie/miniforge3/envs/poromat/lib/python3.10/site-packages/torchvision/image.so, 0x0006): Library not loaded: @rpath/libjpeg.9.dylib
#   Referenced from: <0B7EB158-53DC-3403-8A49-22178CAB4612> /Users/robbie/miniforge3/envs/poromat/lib/python3.10/site-packages/torchvision/image.so
# ...

# %%
poromat.plot(40, 300, 4500, step=0.005, method="interpolation")

# %%
poromat.save_csv(16, 300, 4500, step=0.001, method="lightgbm")
# Out:
# [SAVED] CSV saved to: results/outputs/lightgbm_por16_T300_rate4500_step0.001_lightgbm_20250519_020055.csv
